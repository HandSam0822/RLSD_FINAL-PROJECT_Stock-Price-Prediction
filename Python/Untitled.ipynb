# %%
#導入套件
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#讀檔
positive_TSMC_NEWS = pd.read_csv('/Users/liaoshousan/Desktop/RLSD_PROJECT-StockPrice Prediction/提取出正負面的新聞/台積電正面新聞.csv')
negative_TSMC_NEWS = pd.read_csv('/Users/liaoshousan/Desktop/RLSD_PROJECT-StockPrice Prediction/提取出正負面的新聞/台積電負面新聞.csv')
positive_Foxconn_NEWS = pd.read_csv('/Users/liaoshousan/Desktop/RLSD_PROJECT-StockPrice Prediction/提取出正負面的新聞/鴻海正面新聞.csv')
negative_Foxconn_NEWS = pd.read_csv('/Users/liaoshousan/Desktop/RLSD_PROJECT-StockPrice Prediction/提取出正負面的新聞/鴻海負面新聞.csv')
positive_LARGAN_NEWS = pd.read_csv('/Users/liaoshousan/Desktop/RLSD_PROJECT-StockPrice Prediction/提取出正負面的新聞/大立光正面新聞.csv')
negative_LARGAN_NEWS = pd.read_csv('/Users/liaoshousan/Desktop/RLSD_PROJECT-StockPrice Prediction/提取出正負面的新聞/大立光正面新聞.csv')

Foxconn_PRICE = pd.read_csv('/Users/liaoshousan/Desktop/RLSD_PROJECT-StockPrice Prediction/股價資料/2317_鴻海.csv')
TSMC_PRICE = pd.read_csv('/Users/liaoshousan/Desktop/RLSD_PROJECT-StockPrice Prediction/股價資料/2330_台積電.csv')
LARGAN_PRICE = pd.read_csv('/Users/liaoshousan/Desktop/RLSD_PROJECT-StockPrice Prediction/股價資料/3008_大立光.csv')

# %% [markdown]
# 先用大立光做範例(因為亂碼較少)

# %%
negative_LARGAN_NEWS
# Out:
#      Unnamed: 0                           TITLE        TIME  \
# 0             0                 蘋概三王熄火 台股開盤小漲3點  2019-10-30
# 1             1               台股續創29年半新高 資金行情升溫  2019-10-29
# 2             2             台積電再創新高 台股改寫逾29年來新高  2019-10-30
# 3             3  台積電再飆高台股收漲46.41點 三大法人買超63.04億元  2019-10-30
# 4             4        漲多電子股拉回 台股漲18.85點收11,333  2019-10-29
# ..          ...                             ...         ...
# 332         332                     農曆年後 迎非蘋拉貨潮  2019-01-06
# 333         333                  美陸股報佳音 台股反彈上發條  2019-01-06
# 334         334                  蘋果光不亮 大立光為何不怕？  2019-01-05
# 335         335                    台股拚破底翻 看五大關鍵  2019-01-05
# 336         336              股海常勝軍內資回流 醞釀資金衝浪行情  2019-01-05
#
#                                            DESCRIPTION  \
# 0    市場靜待蘋果財報以及聯準會利率決策會議，台股今日開盤小漲3點，開在11,336.9點，盤面上...
# 1    美國聯準會可望降息，資金行情帶動股市上漲，台股在10月22日收11271點，創29年半新高後...
# 2    電子金融尾盤上揚，台積電再創新高價，台股收在今天最高點，更續創逾29年來新高。法人表示，加權...
# ...
